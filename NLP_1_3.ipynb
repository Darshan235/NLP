# %% [markdown]
# # **NLP 1.3**

# %%
import nltk
import spacy

# %%
text="Technology has rapidly transformed our world, impacting nearly every aspect of daily life. From the way we communicate and access information to how we work and entertain ourselves, digital advancements have created unprecedented opportunities and challenges. The continuous evolution of artificial intelligence, machine learning, and connectivity promises even more profound changes, pushing the boundaries of what's possible and reshaping human society in ways we are only beginning to understand. Adapting to this dynamic landscape requires constant learning and a forward-thinking approach to ensure that innovation serves humanity's best interests"

# %%
word_count = len(text.split())
print(f"The text contains {word_count} words.")
# Out:
# The text contains 89 words.

# %%
lowercase_text = text.lower()
print(lowercase_text)
# Out:
# technology has rapidly transformed our world, impacting nearly every aspect of daily life. from the way we communicate and access information to how we work and entertain ourselves, digital advancements have created unprecedented opportunities and challenges. the continuous evolution of artificial intelligence, machine learning, and connectivity promises even more profound changes, pushing the boundaries of what's possible and reshaping human society in ways we are only beginning to understand. adapting to this dynamic landscape requires constant learning and a forward-thinking approach to ensure that innovation serves humanity's best interests
