# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshan235/NLP/blob/main/NLP_assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import spacy
import matplotlib.pyplot as plt
import pandas as pd
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
essay_text = """The rapid advancement of artificial intelligence (AI) presents both profound opportunities and significant challenges across various sectors. This essay will explore the implications of AI on employment, ethical considerations, and the future of human-computer interaction. Critics argue that AI, through automation, will lead to widespread job displacement, particularly in manufacturing and routine administrative tasks. However, proponents contend that AI will create new jobs and enhance productivity, requiring a workforce equipped with new skills.

Ethical concerns surrounding AI development include algorithmic bias, privacy invasion, and the question of accountability for autonomous systems. The data used to train AI models often reflects societal prejudices, perpetuating and amplifying existing inequalities. Furthermore, the extensive collection and analysis of personal data by AI systems raise serious privacy issues. Determining responsibility when AI systems make errors or cause harm remains a complex legal and philosophical challenge.

The future of human-computer interaction is poised for transformation. AI-powered interfaces, such as intelligent virtual assistants and personalized learning platforms, promise more intuitive and adaptive user experiences. Yet, over-reliance on AI may diminish critical human faculties, such as problem-solving and independent decision-making. Balancing the benefits of AI with the need to preserve essential human capabilities is paramount for a sustainable technological future. Ultimately, the successful integration of AI into society hinges on proactive policy-making, continuous education, and a robust ethical framework that prioritizes human well-being.
"""
print("Essay text loaded successfully into 'essay_text' variable.")
# Out:
# Essay text loaded successfully into 'essay_text' variable.

# %%
nltk.download('punkt_tab')
nltk_tokens = nltk.word_tokenize(essay_text)
print(f"NLTK tokens (first 10): {nltk_tokens[:10]}")
print(f"Total NLTK tokens: {len(nltk_tokens)}")
# Out:
# NLTK tokens (first 10): ['The', 'rapid', 'advancement', 'of', 'artificial', 'intelligence', '(', 'AI', ')', 'presents']
# Total NLTK tokens: 258
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
nltk.download('averaged_perceptron_tagger_eng')
nltk_pos_tags = nltk.pos_tag(nltk_tokens)
print(f"NLTK POS tags (first 10): {nltk_pos_tags[:10]}")
print(f"Total NLTK POS tags: {len(nltk_pos_tags)}")
# Out:
# NLTK POS tags (first 10): [('The', 'DT'), ('rapid', 'JJ'), ('advancement', 'NN'), ('of', 'IN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('(', '('), ('AI', 'NNP'), (')', ')'), ('presents', 'VBZ')]
# Total NLTK POS tags: 258
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
nlp = spacy.load("en_core_web_sm")
spacy_doc = nlp(essay_text)
spacy_tokens = [token.text for token in spacy_doc]
print(f"spaCy tokens (first 10): {spacy_tokens[:10]}")
print(f"Total spaCy tokens: {len(spacy_tokens)}")
# Out:
# spaCy tokens (first 10): ['The', 'rapid', 'advancement', 'of', 'artificial', 'intelligence', '(', 'AI', ')', 'presents']
# Total spaCy tokens: 277

# %%
spacy_pos_tags = [(token.text, token.pos_) for token in spacy_doc]
print(f"spaCy POS tags (first 10): {spacy_pos_tags[:10]}")
print(f"Total spaCy POS tags: {len(spacy_pos_tags)}")
# Out:
# spaCy POS tags (first 10): [('The', 'DET'), ('rapid', 'ADJ'), ('advancement', 'NOUN'), ('of', 'ADP'), ('artificial', 'ADJ'), ('intelligence', 'NOUN'), ('(', 'PUNCT'), ('AI', 'PROPN'), (')', 'PUNCT'), ('presents', 'VERB')]
# Total spaCy POS tags: 277

# %%
nltk_unique_tags = sorted(list(set([tag for word, tag in nltk_pos_tags])))
print(f"Unique NLTK POS Tags: {nltk_unique_tags}")
# Out:
# Unique NLTK POS Tags: ['(', ')', ',', '.', 'CC', 'DT', 'IN', 'JJ', 'MD', 'NN', 'NNP', 'NNS', 'RB', 'RBR', 'TO', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WRB']

# %%
spacy_unique_tags = sorted(list(set([tag for word, tag in spacy_pos_tags])))
print(f"Unique spaCy POS Tags: {spacy_unique_tags}")
# Out:
# Unique spaCy POS Tags: ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'NOUN', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SPACE', 'VERB']

# %%
pos_tag_mapping = {
    'NLTK_NOUN_TAGS': ['NN', 'NNS', 'NNP', 'NNPS'],
    'SPACY_NOUN_TAGS': ['NOUN', 'PROPN'],
    'NLTK_VERB_TAGS': ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'],
    'SPACY_VERB_TAGS': ['VERB', 'AUX'],
    'NLTK_ADJECTIVE_TAGS': ['JJ', 'JJR', 'JJS'],
    'SPACY_ADJECTIVE_TAGS': ['ADJ'],
    'NLTK_ADVERB_TAGS': ['RB', 'RBR', 'RBS'],
    'SPACY_ADVERB_TAGS': ['ADV'],
    'NLTK_PUNCTUATION_TAGS': [',', '.', ':', '(', ')', '``', "''"],
    'SPACY_PUNCTUATION_TAGS': ['PUNCT']
}
print("POS Tag Mapping:")
for key, value in pos_tag_mapping.items():
    print(f"  {key}: {value}")
# Out:
# POS Tag Mapping:
#   NLTK_NOUN_TAGS: ['NN', 'NNS', 'NNP', 'NNPS']
#   SPACY_NOUN_TAGS: ['NOUN', 'PROPN']
#   NLTK_VERB_TAGS: ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
#   SPACY_VERB_TAGS: ['VERB', 'AUX']
#   NLTK_ADJECTIVE_TAGS: ['JJ', 'JJR', 'JJS']
#   SPACY_ADJECTIVE_TAGS: ['ADJ']
#   NLTK_ADVERB_TAGS: ['RB', 'RBR', 'RBS']
#   SPACY_ADVERB_TAGS: ['ADV']
#   NLTK_PUNCTUATION_TAGS: [',', '.', ':', '(', ')', '``', "''"]
#   SPACY_PUNCTUATION_TAGS: ['PUNCT']

# %%
nltk_nouns = []
nltk_verbs = []
spacy_nouns = []
spacy_verbs = []

for word, tag in nltk_pos_tags:
    if tag in pos_tag_mapping['NLTK_NOUN_TAGS']:
        nltk_nouns.append(word.lower())
    elif tag in pos_tag_mapping['NLTK_VERB_TAGS']:
        nltk_verbs.append(word.lower())

for word, tag in spacy_pos_tags:
    if tag in pos_tag_mapping['SPACY_NOUN_TAGS']:
        spacy_nouns.append(word.lower())
    elif tag in pos_tag_mapping['SPACY_VERB_TAGS']:
        spacy_verbs.append(word.lower())

print(f"NLTK Nouns (first 10): {nltk_nouns[:10]}")
print(f"NLTK Verbs (first 10): {nltk_verbs[:10]}")
print(f"spaCy Nouns (first 10): {spacy_nouns[:10]}")
print(f"spaCy Verbs (first 10): {spacy_verbs[:10]}")
# Out:
# NLTK Nouns (first 10): ['advancement', 'intelligence', 'ai', 'opportunities', 'challenges', 'sectors', 'essay', 'implications', 'ai', 'employment']
# NLTK Verbs (first 10): ['presents', 'explore', 'argue', 'lead', 'contend', 'create', 'requiring', 'equipped', 'surrounding', 'include']
# spaCy Nouns (first 10): ['advancement', 'intelligence', 'ai', 'opportunities', 'challenges', 'sectors', 'essay', 'implications', 'ai', 'employment']
# spaCy Verbs (first 10): ['presents', 'will', 'explore', 'argue', 'will', 'lead', 'contend', 'will', 'create', 'enhance']

# %%
from collections import Counter

print("Counter imported successfully.")
# Out:
# Counter imported successfully.

# %%
nltk_noun_freq = Counter(nltk_nouns)
nltk_verb_freq = Counter(nltk_verbs)
spacy_noun_freq = Counter(spacy_nouns)
spacy_verb_freq = Counter(spacy_verbs)

print(f"Most common NLTK Nouns: {nltk_noun_freq.most_common(10)}")
print(f"Most common NLTK Verbs: {nltk_verb_freq.most_common(10)}")
print(f"Most common spaCy Nouns: {spacy_noun_freq.most_common(10)}")
print(f"Most common spaCy Verbs: {spacy_verb_freq.most_common(10)}")
# Out:
# Most common NLTK Nouns: [('ai', 11), ('future', 3), ('systems', 3), ('interaction', 2), ('privacy', 2), ('data', 2), ('advancement', 1), ('intelligence', 1), ('opportunities', 1), ('challenges', 1)]
# Most common NLTK Verbs: [('is', 2), ('presents', 1), ('explore', 1), ('argue', 1), ('lead', 1), ('contend', 1), ('create', 1), ('requiring', 1), ('equipped', 1), ('surrounding', 1)]
# Most common spaCy Nouns: [('ai', 12), ('future', 3), ('systems', 3), ('computer', 2), ('interaction', 2), ('privacy', 2), ('data', 2), ('making', 2), ('advancement', 1), ('intelligence', 1)]
# Most common spaCy Verbs: [('will', 3), ('is', 2), ('presents', 1), ('explore', 1), ('argue', 1), ('lead', 1), ('contend', 1), ('create', 1), ('enhance', 1), ('requiring', 1)]

# %%
df_nltk_nouns = pd.DataFrame(nltk_noun_freq.items(), columns=['Noun', 'Frequency'])
df_nltk_verbs = pd.DataFrame(nltk_verb_freq.items(), columns=['Verb', 'Frequency'])
df_spacy_nouns = pd.DataFrame(spacy_noun_freq.items(), columns=['Noun', 'Frequency'])
df_spacy_verbs = pd.DataFrame(spacy_verb_freq.items(), columns=['Verb', 'Frequency'])

print("NLTK Nouns DataFrame (first 5 rows):")
print(df_nltk_nouns.head())
print("\nNLTK Verbs DataFrame (first 5 rows):")
print(df_nltk_verbs.head())
print("\nspaCy Nouns DataFrame (first 5 rows):")
print(df_spacy_nouns.head())
print("\nspaCy Verbs DataFrame (first 5 rows):")
print(df_spacy_verbs.head())
# Out:
# NLTK Nouns DataFrame (first 5 rows):
#             Noun  Frequency
# 0    advancement          1
# 1   intelligence          1
# 2             ai         11
# 3  opportunities          1
# 4     challenges          1
#
# NLTK Verbs DataFrame (first 5 rows):
#        Verb  Frequency
# 0  presents          1
# 1   explore          1
# 2     argue          1
# 3      lead          1
# 4   contend          1
#
# spaCy Nouns DataFrame (first 5 rows):
#             Noun  Frequency
# 0    advancement          1
# 1   intelligence          1
# 2             ai         12
# 3  opportunities          1
# 4     challenges          1
#
# spaCy Verbs DataFrame (first 5 rows):
#        Verb  Frequency
# 0  presents          1
# 1      will          3
# 2   explore          1
# 3     argue          1
# 4      lead          1

# %%
top_n = 10

# Plot NLTK Noun Frequencies
plt.figure(figsize=(12, 6))
plt.bar(df_nltk_nouns['Noun'].head(top_n), df_nltk_nouns['Frequency'].head(top_n), color='skyblue')
plt.xlabel('NLTK Noun')
plt.ylabel('Frequency')
plt.title(f'Top {top_n} NLTK Noun Frequencies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plot NLTK Verb Frequencies
plt.figure(figsize=(12, 6))
plt.bar(df_nltk_verbs['Verb'].head(top_n), df_nltk_verbs['Frequency'].head(top_n), color='lightcoral')
plt.xlabel('NLTK Verb')
plt.ylabel('Frequency')
plt.title(f'Top {top_n} NLTK Verb Frequencies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plot spaCy Noun Frequencies
plt.figure(figsize=(12, 6))
plt.bar(df_spacy_nouns['Noun'].head(top_n), df_spacy_nouns['Frequency'].head(top_n), color='lightgreen')
plt.xlabel('spaCy Noun')
plt.ylabel('Frequency')
plt.title(f'Top {top_n} spaCy Noun Frequencies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plot spaCy Verb Frequencies
plt.figure(figsize=(12, 6))
plt.bar(df_spacy_verbs['Verb'].head(top_n), df_spacy_verbs['Frequency'].head(top_n), color='mediumpurple')
plt.xlabel('spaCy Verb')
plt.ylabel('Frequency')
plt.title(f'Top {top_n} spaCy Verb Frequencies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
